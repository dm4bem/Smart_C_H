# %% [markdown]
# # Thermal Model AnalysisThis notebook runs the thermal model analysis using the `Code.py` script.

# %%
# Import necessary librariesimport numpy as np# Run the Code.py script and handle errorstry:    %run Code.pyexcept FileNotFoundError:    print('Error: Code.py script not found.')except Exception as e:    print(f'Error while running Code.py: {e}')# Ensure the necessary variables are definedtry:    A    G    C    b    f    θ    q    As    Bs    Cs    Dsexcept NameError as e:    print(f'Error: {e}')# Display A matrixprint("A matrix (connectivity):")print(A)# Display G matrixprint("\nG matrix (conductance):")print(G)# Display C matrixprint("\nC matrix (capacitances):")print(C)# Display b matrixprint("\nb matrix (external temperatures and sources):")print(b)# Display f matrixprint("\nf matrix (absorbed solar radiation and internal sources):")print(f)# Display individual room temperaturesprint("\nIndoor air temperatures:")print(f"Room A temperature: {θ[3]} °C")print(f"Room B temperature: {θ[7]} °C")# Display thermal loadcontroller = 7  # Assuming the controller is defined at index 7, update as neededprint(f"\nController thermal load (Room B): {q[controller]} W")# Display state-space matricesprint("\nState-space representation matrices:")print("As:\n", As)print("Bs:\n", Bs)print("Cs:\n", Cs)print("Ds:\n", Ds)

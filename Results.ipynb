# %% [markdown]
# # Thermal Model AnalysisThis notebook runs the thermal model analysis using the `Code.py` script.

# %%
# Import necessary librariesimport numpy as np# Run the Code.py script%run Code.py# Display A matrixprint("A matrix (connectivity):")print(A)# Display G matrixprint("\nG matrix (conductance):")print(G)# Display C matrixprint("\nC matrix (capacitances):")print(C)# Display b matrixprint("\nb matrix (external temperatures and sources):")print(b)# Display f matrixprint("\nf matrix (absorbed solar radiation and internal sources):")print(f)# Display individual room temperaturesprint("\nIndoor air temperatures:")print("Room A temperature:", θ[3], "°C")print("Room B temperature:", θ[7], "°C")# Display thermal loadprint("\nController thermal load (Room B):", q[controller], "W")# Display state-space matricesprint("\nState-space representation matrices:")print("As:\n", As)print("Bs:\n", Bs)print("Cs:\n", Cs)print("Ds:\n", Ds)
